# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd

# %%
url = 'https://www.scrapethissite.com/pages/ajax-javascript/#2015'
driver = webdriver.Chrome()
driver.get(url)

driver.implicitly_wait(10)

#Find all the rows
films = driver.find_elements(By.XPATH, '//*[@id="table-body"]/tr')

film_list_global = []

# Iterate through each film row and extract details
for film in films:
    film_dict = {}
    film_dict['title'] = film.find_element(By.XPATH, './td[1]').text
    film_dict['nominations'] = film.find_element(By.XPATH, './td[2]').text
    film_dict['awards'] = film.find_element(By.XPATH, './td[3]').text
    film_list_global.append(film_dict)

# Close the browser
driver.quit()

# Create a DataFrame from the list of dictionaries
df = pd.DataFrame(film_list_global)

# Save the DataFrame to CSV
df.to_csv('films_2015.csv')

# Print the DataFrame
print(df)
# Out:
#                                             title nominations awards
# 0                                       Spotlight           6      2
# 1                              Mad Max: Fury Road          10      6
# 2                                    The Revenant          12      3
# 3                                 Bridge of Spies           6      1
# 4                                   The Big Short           5      1
# 5                                 The Danish Girl           4      1
# 6                                            Room           4      1
# 7                                      Ex Machina           2      1
# 8                               The Hateful Eight           2      1
# 9                                      Inside Out           2      1
# 10                                            Amy           1      1
# 11                                     Bear Story           1      1
# 12  A Girl in the River: The Price of Forgiveness           1      1
# ...

# %%
url = 'https://www.scrapethissite.com/pages/ajax-javascript/#2014'
driver = webdriver.Chrome()
driver.get(url)

driver.implicitly_wait(10)

# Find all rows in the table body
films = driver.find_elements(By.XPATH, '//*[@id="table-body"]/tr')

film_list_global = []

# Iterate through each film row and extract details
for film in films:
    film_dict = {}
    film_dict['title'] = film.find_element(By.XPATH, './td[1]').text
    film_dict['nominations'] = film.find_element(By.XPATH, './td[2]').text
    film_dict['awards'] = film.find_element(By.XPATH, './td[3]').text
    film_list_global.append(film_dict)

# Close the browser
driver.quit()

# Create a DataFrame from the list of dictionaries
df = pd.DataFrame(film_list_global)

# Save the DataFrame to CSV
df.to_csv('films_2014.csv')

# Print the DataFrame
print(df)
# Out:
#                                title nominations awards
# 0                            Birdman           9      4
# 1           The Grand Budapest Hotel           9      4
# 2                           Whiplash           5      3
# 3                 The Imitation Game           8      1
# 4                    American Sniper           6      1
# 5                            Boyhood           6      1
# 6                       Interstellar           5      1
# 7           The Theory of Everything           5      1
# 8                                Ida           2      1
# 9                              Selma           2      1
# 10                       Citizenfour           1      1
# 11                        Big Hero 6           1      1
# 12  Crisis Hotline: Veterans Press 1           1      1
# 13                    The Phone Call           1      1
# 14                       Still Alice           1      1
# 15                             Feast           1      1

# %%
url = 'https://www.scrapethissite.com/pages/ajax-javascript/#2013'
driver = webdriver.Chrome()
driver.get(url)

driver.implicitly_wait(10)

# Find all rows in the table body
films = driver.find_elements(By.XPATH, '//*[@id="table-body"]/tr')

film_list_global = []

# Iterate through each film row and extract details
for film in films:
    film_dict = {}
    film_dict['title'] = film.find_element(By.XPATH, './td[1]').text
    film_dict['nominations'] = film.find_element(By.XPATH, './td[2]').text
    film_dict['awards'] = film.find_element(By.XPATH, './td[3]').text
    film_list_global.append(film_dict)

# Close the browser
driver.quit()

# Create a DataFrame from the list of dictionaries
df = pd.DataFrame(film_list_global)

# Save the DataFrame to CSV
df.to_csv('films_2013.csv')

# Print the DataFrame
print(df)
# Out:
#                                         title nominations awards
# 0                            12 Years a Slave           9      3
# 1                                     Gravity          10      7
# 2                          Dallas Buyers Club           6      3
# 3                                      Frozen           2      2
# 4                            The Great Gatsby           2      2
# 5                                         Her           5      1
# 6                                Blue Jasmine           3      1
# 7                                   Mr Hublot           1      1
# 8   The Lady in Number 6: Music Saved My Life           1      1
# 9                                      Helium           1      1
# 10                           The Great Beauty           1      1
# 11                       20 Feet from Stardom           1      1

# %%
url = 'https://www.scrapethissite.com/pages/ajax-javascript/#2012'
driver = webdriver.Chrome()
driver.get(url)

driver.implicitly_wait(10)

# Find all rows in the table body
films = driver.find_elements(By.XPATH, '//*[@id="table-body"]/tr')

film_list_global = []

# Iterate through each film row and extract details
for film in films:
    film_dict = {}
    film_dict['title'] = film.find_element(By.XPATH, './td[1]').text
    film_dict['nominations'] = film.find_element(By.XPATH, './td[2]').text
    film_dict['awards'] = film.find_element(By.XPATH, './td[3]').text
    film_list_global.append(film_dict)

# Close the browser
driver.quit()

# Create a DataFrame from the list of dictionaries
df = pd.DataFrame(film_list_global)

# Save the DataFrame to CSV
df.to_csv('films_2012.csv')

# Print the DataFrame
print(df)
# Out:
#                       title nominations awards
# 0                      Argo           7      3
# 1                Life of Pi          11      4
# 2            Les Misérables           8      3
# 3                   Lincoln          12      2
# 4          Django Unchained           5      2
# 5                   Skyfall           5      2
# 6   Silver Linings Playbook           8      1
# 7          Zero Dark Thirty           5      1
# 8                     Amour           5      1
# 9             Anna Karenina           4      1
# 10                 Paperman           1      1
# 11                    Brave           1      1
# 12  Searching for Sugar Man           1      1
# 13                 Inocente           1      1
# 14                   Curfew           1      1

# %%
url = 'https://www.scrapethissite.com/pages/ajax-javascript/#2011'
driver = webdriver.Chrome()
driver.get(url)

driver.implicitly_wait(10)

# Find all rows in the table body
films = driver.find_elements(By.XPATH, '//*[@id="table-body"]/tr')

film_list_global = []

# Iterate through each film row and extract details
for film in films:
    film_dict = {}
    film_dict['title'] = film.find_element(By.XPATH, './td[1]').text
    film_dict['nominations'] = film.find_element(By.XPATH, './td[2]').text
    film_dict['awards'] = film.find_element(By.XPATH, './td[3]').text
    film_list_global.append(film_dict)

# Close the browser
driver.quit()

# Create a DataFrame from the list of dictionaries
df = pd.DataFrame(film_list_global)

# Save the DataFrame to CSV
df.to_csv('films_2011.csv')

# Print the DataFrame
print(df)
# Out:
#                                                 title nominations awards
# 0                                          The Artist          10      5
# 1                                                Hugo          11      5
# 2                                       The Iron Lady           2      2
# 3                                     The Descendants           5      1
# 4                     The Girl with the Dragon Tattoo           5      1
# 5                                   Midnight in Paris           4      1
# 6                                            The Help           4      1
# 7                                        A Separation           2      1
# 8   The Fantastic Flying Books of Mr. Morris Lessmore           1      1
# 9                                           The Shore           1      1
# 10                                         Undefeated           1      1
# 11                                        The Muppets           1      1
# ...

# %%
url = 'https://www.scrapethissite.com/pages/ajax-javascript/#2010'
driver = webdriver.Chrome()
driver.get(url)

driver.implicitly_wait(10)

# Find all rows in the table body
films = driver.find_elements(By.XPATH, '//*[@id="table-body"]/tr')

film_list_global = []

# Iterate through each film row and extract details
for film in films:
    film_dict = {}
    film_dict['title'] = film.find_element(By.XPATH, './td[1]').text
    film_dict['nominations'] = film.find_element(By.XPATH, './td[2]').text
    film_dict['awards'] = film.find_element(By.XPATH, './td[3]').text
    film_list_global.append(film_dict)

# Close the browser
driver.quit()

# Create a DataFrame from the list of dictionaries
df = pd.DataFrame(film_list_global)

# Save the DataFrame to CSV
df.to_csv('films_2010.csv')

# Print the DataFrame
print(df)
# Out:
#                   title nominations awards
# 0     The King's Speech          12      4
# 1             Inception           8      4
# 2    The Social Network           8      3
# 3           The Fighter           7      2
# 4           Toy Story 3           5      2
# 5   Alice in Wonderland           3      2
# 6            Black Swan           5      1
# 7     In a Better World           1      1
# 8        The Lost Thing           1      1
# 9           God of Love           1      1
# 10          The Wolfman           1      1
# 11    Strangers No More           1      1
# 12           Inside Job           1      1
